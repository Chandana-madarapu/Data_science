# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandana-madarapu/Data_science/blob/main/Basics_of_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Prime Numbers

# %%
num = int(input("Enter a number: "))

if num > 1:
    for i in range(2, num):
        if num % i == 0:
            print(num, "is not a prime number.")
            break
    else:
        print(num, "is a prime number.")
else:
    print(num, "is not a prime number.")
# Out:
# Enter a number: 1
# 1 is not a prime number.

# %% [markdown]
# 2. Product of Random Numbers

# %%
import random

a = random.randint(1, 10)     # random integer between 1 and 10
b = random.randint(1, 10)

print("What is", a, "×", b, "?")
answer = int(input("Enter your answer: "))

if answer == a * b:
    print("Correct!")
else:
    print("Wrong! The right answer is", a * b)
# Out:
# What is 1 × 2 ?
# Enter your answer: 3
# Wrong! The right answer is 2

# %% [markdown]
# 3. Squares of Even/Odd Numbers

# %%
for i in range(100, 201):
    if i % 2 == 0:       # even numbers
        print(i, "square is", i * i)


#for i in range(100,201):
    #if i % 2 ! == 0:      #odd numbers
       # print(n, "square is", i * i)
# Out:
# 100 square is 10000
# 102 square is 10404
# 104 square is 10816
# 106 square is 11236
# 108 square is 11664
# 110 square is 12100
# 112 square is 12544
# 114 square is 12996
# 116 square is 13456
# 118 square is 13924
# 120 square is 14400
# 122 square is 14884
# 124 square is 15376
# 126 square is 15876
# 128 square is 16384
# 130 square is 16900
# 132 square is 17424
# 134 square is 17956
# 136 square is 18496
# 138 square is 19044
# 140 square is 19600
# 142 square is 20164
# 144 square is 20736
# 146 square is 21316
# 148 square is 21904
# 150 square is 22500
# 152 square is 23104
# 154 square is 23716
# 156 square is 24336
# 158 square is 24964
# 160 square is 25600
# 162 square is 26244
# 164 square is 26896
# 166 square is 27556
# 168 square is 28224
# 170 square is 28900
# 172 square is 29584
# 174 square is 30276
# 176 square is 30976
# 178 square is 31684
# 180 square is 32400
# 182 square is 33124
# 184 square is 33856
# 186 square is 34596
# 188 square is 35344
# ...

# %% [markdown]
# 4. Word Counter

# %%
#enter a text
text = input("Enter a text: ")
words = text.split()
count = {}

for w in words:
    w = w.lower().strip(".,!?")
    if w in count:
        count[w] += 1
    else:
        count[w] = 1

for k, v in count.items():
    print(k, ":", v)
# Out:
# Enter a text: hi im chandana
# hi : 1
# im : 1
# chandana : 1

# %% [markdown]
# 5. Check for Palindrome

# %%
word = input("Enter a word or phrase: ")

# to remove spaces and make lowercase
clean = ""
for ch in word:
    if ch.isalnum():
        clean += ch.lower()

if clean == clean[::-1]:
    print("It is a palindrome.")
else:
    print("It is not a palindrome.")
# Out:
# Enter a word or phrase: racecar
# It is a palindrome.
