# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandana-madarapu/Data_science/blob/main/Association_rules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel('Online retail.xlsx')
df.head()
# Out:
#   shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# 0                             burgers,meatballs,eggs
# 1                                            chutney
# 2                                     turkey,avocado
# 3  mineral water,milk,energy bar,whole wheat rice...
# 4                                     low fat yogurt

# %%
# Handle missing values: fill NaN with an empty string or drop the rows
df.fillna('', inplace=True)

# Remove duplicate rows
df.drop_duplicates(inplace=True)

# Convert the dataframe into a list of lists (transactions)
transactions = []
for index, row in df.iterrows():
    # Split the single string of items into a list of items
    items = [item.strip() for item in row[0].split(',') if item.strip()] # Split and remove leading/trailing whitespace, and exclude empty items
    if items: # Only add transaction if it's not empty after stripping
        transactions.append(items)

print("Number of transactions after preprocessing:", len(transactions))
print("First 5 transactions after preprocessing:", transactions[:5])
# Out:
# /tmp/ipython-input-3997437469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   items = [item.strip() for item in row[0].split(',') if item.strip()] # Split and remove leading/trailing whitespace, and exclude empty items
# Number of transactions after preprocessing: 5175
# First 5 transactions after preprocessing: [['burgers', 'meatballs', 'eggs'], ['chutney'], ['turkey', 'avocado'], ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'], ['low fat yogurt']]

# %%
# !pip install apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5954 sha256=f0c1f712b6b57ca6759b869a3756e64c643a530d6ee86344e5241a548a4b5831
#   Stored in directory: /root/.cache/pip/wheels/7f/49/e3/42c73b19a264de37129fadaa0c52f26cf50e87de08fb9804af
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
from apyori import apriori
# Apply the Apriori algorithm
rules = apriori(transactions, min_support=0.004, min_confidence=0.2, min_lift=3, min_length=2)

# Convert the rules to a list
results = list(rules)

# Print the first few rules
print("Number of rules found:", len(results))
print("First 5 rules:")
for i in range(min(5, len(results))):
    print(results[i])
# Out:
# Number of rules found: 30
# First 5 rules:
# RelationRecord(items=frozenset({'chicken', 'light cream'}), support=0.006570048309178744, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29310344827586204, lift=3.4949547115843)])
# RelationRecord(items=frozenset({'escalope', 'mushroom cream sauce'}), support=0.006956521739130435, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.28800000000000003, lift=3.4341013824884796)])
# RelationRecord(items=frozenset({'pasta', 'escalope'}), support=0.00502415458937198, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.28888888888888886, lift=3.444700460829493)])
# RelationRecord(items=frozenset({'fromage blanc', 'honey'}), support=0.004830917874396135, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fromage blanc'}), items_add=frozenset({'honey'}), confidence=0.24752475247524752, lift=3.801010664864706)])
# RelationRecord(items=frozenset({'whole wheat pasta', 'olive oil'}), support=0.011014492753623189, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole wheat pasta'}), items_add=frozenset({'olive oil'}), confidence=0.27142857142857146, lift=3.100756859035005)])

# %%
# Function to extract rule information and lift
def extract_rule_info(relation_record):
    rules_list = []
    for ordered_stat in relation_record.ordered_statistics:
        rules_list.append({
            "items_base": list(ordered_stat.items_base),
            "items_add": list(ordered_stat.items_add),
            "support": relation_record.support,
            "confidence": ordered_stat.confidence,
            "lift": ordered_stat.lift
        })
    return rules_list

# Extract all rules with their metrics
all_rules = []
for record in results:
    all_rules.extend(extract_rule_info(record))

# Sort the rules by lift in descending order
sorted_rules = sorted(all_rules, key=lambda x: x['lift'], reverse=True)

# Display the sorted rules
print("Association Rules (Sorted by Lift):")
for i, rule in enumerate(sorted_rules):
    print(f"Rule {i+1}: {rule['items_base']} -> {rule['items_add']}")
    print(f"Support: {rule['support']:.4f}, Confidence: {rule['confidence']:.4f}, Lift: {rule['lift']:.4f}")
    print("-" * 20)
# Out:
# Association Rules (Sorted by Lift):
# Rule 1: ['frozen vegetables', 'soup'] -> ['milk', 'mineral water']
# Support: 0.0044, Confidence: 0.3833, Lift: 5.6517
# --------------------
# Rule 2: ['mineral water', 'whole wheat pasta'] -> ['olive oil']
# Support: 0.0054, Confidence: 0.3944, Lift: 4.5052
# --------------------
# Rule 3: ['frozen vegetables', 'olive oil'] -> ['milk', 'mineral water']
# Support: 0.0048, Confidence: 0.2941, Lift: 4.3363
# --------------------
# Rule 4: ['pasta'] -> ['shrimp']
# Support: 0.0071, Confidence: 0.4111, Lift: 4.1634
# --------------------
# Rule 5: ['milk', 'soup'] -> ['frozen vegetables', 'mineral water']
# Support: 0.0044, Confidence: 0.2072, Lift: 4.1084
# --------------------
# Rule 6: ['tomato sauce'] -> ['ground beef', 'spaghetti']
# Support: 0.0044, Confidence: 0.2212, Lift: 3.9601
# --------------------
# Rule 7: ['frozen vegetables', 'milk', 'mineral water'] -> ['soup']
# Support: 0.0044, Confidence: 0.2771, Lift: 3.9075
# --------------------
# Rule 8: ['ground beef', 'shrimp'] -> ['herb & pepper']
# Support: 0.0043, Confidence: 0.2558, Lift: 3.8484
# --------------------
# Rule 9: ['fromage blanc'] -> ['honey']
# Support: 0.0048, Confidence: 0.2475, Lift: 3.8010
# --------------------
# Rule 10: ['tomato sauce'] -> ['chocolate', 'spaghetti']
# Support: 0.0041, Confidence: 0.2019, Lift: 3.6158
# --------------------
# Rule 11: ['tomato sauce', 'spaghetti'] -> ['ground beef']
# Support: 0.0044, Confidence: 0.4894, Lift: 3.6023
# --------------------
# Rule 12: ['frozen vegetables', 'mineral water', 'soup'] -> ['milk']
# Support: 0.0044, Confidence: 0.6053, Lift: 3.5594
# --------------------
# Rule 13: ['light cream'] -> ['chicken']
# Support: 0.0066, Confidence: 0.2931, Lift: 3.4950
# --------------------
# Rule 14: ['ground beef', 'french fries'] -> ['herb & pepper']
# Support: 0.0046, Confidence: 0.2308, Lift: 3.4716
# --------------------
# Rule 15: ['pasta'] -> ['escalope']
# Support: 0.0050, Confidence: 0.2889, Lift: 3.4447
# --------------------
# Rule 16: ['frozen vegetables', 'milk', 'mineral water'] -> ['olive oil']
# Support: 0.0048, Confidence: 0.3012, Lift: 3.4409
# --------------------
# Rule 17: ['frozen vegetables', 'herb & pepper'] -> ['ground beef']
# Support: 0.0041, Confidence: 0.4667, Lift: 3.4353
# --------------------
# Rule 18: ['spaghetti', 'mineral water', 'herb & pepper'] -> ['ground beef']
# Support: 0.0041, Confidence: 0.4667, Lift: 3.4353
# --------------------
# Rule 19: ['mushroom cream sauce'] -> ['escalope']
# Support: 0.0070, Confidence: 0.2880, Lift: 3.4341
# --------------------
# Rule 20: ['french fries', 'herb & pepper'] -> ['ground beef']
# Support: 0.0046, Confidence: 0.4615, Lift: 3.3975
# --------------------
# Rule 21: ['cereals', 'spaghetti'] -> ['ground beef']
# Support: 0.0044, Confidence: 0.4600, Lift: 3.3862
# --------------------
# Rule 22: ['frozen vegetables', 'olive oil'] -> ['chocolate', 'mineral water']
# Support: 0.0041, Confidence: 0.2471, Lift: 3.3734
# --------------------
# Rule 23: ['frozen vegetables', 'mineral water', 'chocolate'] -> ['shrimp']
# Support: 0.0046, Confidence: 0.3288, Lift: 3.3295
# --------------------
# Rule 24: ['frozen vegetables', 'mineral water', 'chocolate'] -> ['olive oil']
# Support: 0.0041, Confidence: 0.2877, Lift: 3.2863
# --------------------
# Rule 25: ['frozen vegetables', 'ground beef'] -> ['milk', 'mineral water']
# Support: 0.0054, Confidence: 0.2205, Lift: 3.2506
# --------------------
# Rule 26: ['chocolate', 'herb & pepper'] -> ['ground beef']
# Support: 0.0058, Confidence: 0.4412, Lift: 3.2476
# --------------------
# Rule 27: ['frozen vegetables', 'cake'] -> ['tomatoes']
# Support: 0.0044, Confidence: 0.2987, Lift: 3.2474
# --------------------
# Rule 28: ['mineral water', 'chocolate', 'shrimp'] -> ['frozen vegetables']
# Support: 0.0046, Confidence: 0.4211, Lift: 3.2425
# --------------------
# Rule 29: ['milk', 'tomatoes'] -> ['soup']
# Support: 0.0044, Confidence: 0.2233, Lift: 3.1487
# --------------------
# Rule 30: ['ground beef', 'eggs'] -> ['herb & pepper']
# Support: 0.0060, Confidence: 0.2081, Lift: 3.1299
# --------------------
# Rule 31: ['whole wheat pasta'] -> ['olive oil']
# Support: 0.0110, Confidence: 0.2714, Lift: 3.1008
# --------------------
# Rule 32: ['ground beef', 'tomatoes'] -> ['mineral water', 'spaghetti']
# Support: 0.0044, Confidence: 0.2614, Lift: 3.0740
# --------------------
# Rule 33: ['frozen vegetables', 'ground beef'] -> ['mineral water', 'spaghetti']
# Support: 0.0064, Confidence: 0.2598, Lift: 3.0561
# --------------------
# Rule 34: ['shrimp', 'herb & pepper'] -> ['ground beef']
# Support: 0.0043, Confidence: 0.4151, Lift: 3.0556
# --------------------
# Rule 35: ['frozen smoothie', 'spaghetti'] -> ['milk', 'mineral water']
# Support: 0.0046, Confidence: 0.2069, Lift: 3.0504
# --------------------
# Rule 36: ['pancakes', 'olive oil'] -> ['mineral water', 'spaghetti']
# Support: 0.0041, Confidence: 0.2593, Lift: 3.0492
# --------------------
# Rule 37: ['milk', 'olive oil'] -> ['soup']
# Support: 0.0052, Confidence: 0.2160, Lift: 3.0458
# --------------------
# Rule 38: ['ground beef', 'shrimp'] -> ['mineral water', 'spaghetti']
# Support: 0.0043, Confidence: 0.2558, Lift: 3.0087
# --------------------
# Rule 39: ['milk', 'mineral water', 'olive oil'] -> ['frozen vegetables']
# Support: 0.0048, Confidence: 0.3906, Lift: 3.0082
# --------------------
# Rule 40: ['spaghetti', 'mineral water', 'shrimp'] -> ['frozen vegetables']
# Support: 0.0048, Confidence: 0.3906, Lift: 3.0082
# --------------------
# Rule 41: ['frozen vegetables', 'mineral water', 'olive oil'] -> ['milk']
# Support: 0.0048, Confidence: 0.5102, Lift: 3.0003
# --------------------

# %% [markdown]
# ## Conclusion
#
# In this assignment, we applied Association Rule Mining using the Apriori algorithm on the Online Retail dataset.
# We successfully preprocessed the data, generated frequent itemsets, and extracted association rules with support, confidence, and lift measures.
#
# Key takeaways:
# - Rules such as `{pasta} → {shrimp}` and `{fromage blanc} → {honey}` reveal meaningful patterns in customer purchasing behavior.
# - High lift values indicate strong associations that can guide **product bundling**, **cross-selling**, **store layout optimization**, and **targeted promotions**.
# - Insights from these rules can help retailers improve the shopping experience, boost sales, and optimize inventory management.
#
# Overall, association rules provide a powerful way to uncover hidden patterns in transactional data and translate them into actionable business strategies.

# %% [markdown]
# **Q1. What is Lift and why is it important in Association Rules?**
# - **Lift** measures how much more likely two items are bought together compared to random chance.
# - **Formula:**
#   \[
#   Lift(A → B) = \frac{Confidence(A → B)}{Support(B)}
#   \]
# - nterpretation
#
# Lift > 1 → A and B occur together more often than expected (positive association).
#
# Lift = 1 → No relationship (independent).
#
# Lift < 1 → A and B occur together less often than expected (negative association).
#
# Importance
#
# Lift shows the strength and usefulness of the rule.
#
# Confidence alone can be misleading; lift helps confirm if the rule is actually meaningful.
#
# Helps identify true patterns rather than those occurring just because items are popular.
#
# **Q2. What is Support and Confidence? How are they calculated?**
# - **Support(A → B):** Fraction of transactions that include both A and B.
#   \[
#   Support(A → B) = \frac{Transactions(A ∩ B)}{Total Transactions}
#   \]
#
# - **Confidence(A → B):** Probability that a customer buys B given that they bought A.
#   \[
#   Confidence(A → B) = \frac{Support(A ∩ B)}{Support(A)}
#   \]
#
#
# **Q3. What are some limitations or challenges of Association Rule Mining?**
# 1. Generates Too Many Rules: Thousands of rules may be produced; many are irrelevant or not useful.
#
# 2. Requires Setting Thresholds: Choosing minimum support and confidence values affects results.
# Too high → important patterns missed.
# Too low → too many noisy rules.
#
# 3. Ignores Item Position or Order: Market basket analysis only captures “what items occurred together,” not the order of purchase.
#
# 4. No Causality:Association ≠ causation.
# Rules only show correlation, not why items are bought together.
#
# 5. Not Suitable for Rare Events: Rare but valuable combinations may be lost due to low support.
#
# 6. Computationally Expensive: Large datasets → huge number of itemset combinations → heavy computation.
